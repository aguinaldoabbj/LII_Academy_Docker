# %%
import sqlalchemy
import pandas as pd

# %%
mysql = sqlalchemy.create_engine('mysql+pymysql://root:example@mysqldb/mysql')

# %%
mysql.table_names()
# Out:
# ['columns_priv',
#  'component',
#  'db',
#  'default_roles',
#  'engine_cost',
#  'func',
#  'general_log',
#  'global_grants',
#  'gtid_executed',
#  'help_category',
#  'help_keyword',
#  'help_relation',
#  'help_topic',
#  'innodb_index_stats',
#  'innodb_table_stats',
#  'password_history',
#  'plugin',
#  'procs_priv',
#  'proxies_priv',
#  'role_edges',
#  'server_cost',
#  'servers',
#  'slave_master_info',
#  'slave_relay_log_info',
#  'slave_worker_info',
#  'slow_log',
#  'tables_priv',
#  'time_zone',
#  'time_zone_leap_second',
#  'time_zone_name',
#  'time_zone_transition',
#  'time_zone_transition_type',
#  'user']

# %%
df = pd.read_sql_table('help_category', mysql)

# %%
df
# Out:
#     help_category_id                                   name  \
# 0                  0                               Contents
# 1                  1                          Help Metadata
# 2                  2                             Data Types
# 3                  3                         Administration
# 4                  4                     Language Structure
# 5                  5                    Geographic Features
# 6                  6                                    MBR
# 7                  7                                    WKT
# 8                  8                              Functions
# 9                  9                   Comparison Operators
# 10                10                      Logical Operators
# 11                11                 Control Flow Functions
# 12                12                       String Functions
# 13                13                      Numeric Functions
# 14                14                Date and Time Functions
# ...
